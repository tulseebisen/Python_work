# %% [markdown]
# # Datastructures in Python

# %%
#Import library
from IPython.display import Image
# Load image from local storage
Image(filename = "C:/Users/admin/Desktop/TreeStructure-Data-Structures-in-Python-Edureka1.png", width = 800, height = 400)

# %% [markdown]
# # Inbuilt Datastructures in Python

# %%
"""Organizing, managing and storing data is important as it enables easier access and efficient modifications.
Data Structures allows you to organize your data in such a way that enables you to store collections of data,
relate them and perform operations on them accordingly.
"""

# %%
"""Python has implicit support for Data Structures which enable you to store and access data.
These structures are called 
1)List, 
2)Dictionary, 
3)Tuple and 
4)Set
"""

# %% [markdown]
# |SNo| Sentence   | List   | Dictionary   | Tuple   |Set|
# |:---|:-------------|:-----------|:------|:------|:------|
# | 1 | Definition | Lists can be used to store  any type of object       | collection of key-value pairs,works as an associative array  | collection of different type of items   |  Sets are used to store multiple items in a single variable     |
# | 2 | Written in  | []    | {"key name": value}   | ()    |    {}    |
# | 3 | Syntax | list1 = [1,"a",3.2,True]      | dict1 = {"key name": value}   | tup1 = (1,"a",3.2,True)    | set1 = {7,568,"abc",3,False}     |
# | 4 | Can store  |different data types    | different data types   | different data types     |  different data types      |
# |5 | Duplicate values | allowed       | not allowed    | allowed     |    not allowed   |
# | 6 | Order  | ordered   | unordered   | ordered   |   unordered     |
# | 7 | Indexing | possible      | can be indexed by keys   | possible     |Not possible       |
# | 8 | slicing  | possible   | Not possible   |possible     | Not possible       |
# |9 | Mutable/immutable  | Mutable   | Mutable   | Immutable    |Mutable(only add and remove)        |
